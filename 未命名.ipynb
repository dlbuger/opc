# %%
import OpenOPC

# %%
opc = OpenOPC.open_client('Intellution.IntellutionGatewayOPCServer')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\Pyro4\socketutil.py in getIpAddress(hostname, workaround127, ipVersion)
#     101             ipVersion = 0
# --> 102         return getaddr(config.PREFER_IP_VERSION) if ipVersion is None else getaddr(ipVersion)
#     103     except socket.gaierror:
#
# C:\ProgramData\Anaconda3\lib\site-packages\Pyro4\socketutil.py in getaddr(ipVersion)
#      93             raise ValueError("unknown value for argument ipVersion.")
# ---> 94         ip = socket.getaddrinfo(hostname or socket.gethostname(), 80, family, socket.SOCK_STREAM, socket.SOL_TCP)[0][4][0]
#      95         if workaround127 and (ip.startswith("127.") or ip == "0.0.0.0"):
#
# C:\ProgramData\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# ...
